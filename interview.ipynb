# %%
from selenium import webdriver
import time
import datetime
import pandas as pd

browser = webdriver.Firefox()
browser.get('https://www.jobplanet.co.kr/')
browser.maximize_window()
browser.implicitly_wait(6)  # seconds

# %%
# Click the link to go to the login form
login_link = browser.find_element_by_css_selector('a.btn_txt.login')
login_link.click()

# %%
# id
username_input = browser.find_element_by_css_selector('input#user_email')
username_input.send_keys("rcnd@naver.com")

# %%
# password
password_input = browser.find_element_by_css_selector('input#user_password')
password_input.send_keys("71012154ssb") 

browser.find_element_by_class_name('btn_sign_up').click()

# %%
browser.get('https://www.jobplanet.co.kr/companies/3480/interviews?page=1')

# %%
jobplanet_df = pd.DataFrame(columns=["role", "date", "level", "main", "question", "answer"], )

# %%
for board_number in range(1,5):
    browser.get("https://www.jobplanet.co.kr/companies/3480/interviews?page=&page=" + str(board_number))
    time.sleep(0.1)
    
    contents = browser.find_elements_by_css_selector('section.content_ty4.content_ty4_1.video_ad_content')

    for i in range(len(contents)):
        try:
            role = contents[i].find_element_by_css_selector("span.txt1").text.split("|")[0].split("  / ")[0]
            date = contents[i].find_element_by_css_selector("span.txt1").text.split("| ")[-1]
            level = contents[i].find_element_by_css_selector("span.blo_txt2.us_txt_mr").text # 면접 난이도
            main = contents[i].find_element_by_css_selector("h2.us_label ").text
            question = contents[i].find_element_by_css_selector("dd.df1").text # 면접 질문
            answer = contents[i].find_element_by_css_selector("span.answer.mobile_full_content.notranslate").text # 면접 질문 
            
        except:
            answer = ""

        jobplanet_df.loc[len(jobplanet_df)] = [role, date, level, main, question, answer]

    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-8-bfd5a6f133c3> in <module>
#       1 for board_number in range(1,5):
# ----> 2     browser.get("https://www.jobplanet.co.kr/companies/3480/interviews?page=&page=" + str(board_number))
#       3     time.sleep(0.1)
#       4
#       5     contents = browser.find_elements_by_css_selector('section.content_ty4.content_ty4_1.video_ad_content')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: Failed to write response to stream

# %%
jobplanet_df
# Out:
#          role        date   level  \
# 0       영업/제휴  2019/10/28      보통
# 1       금융/재무  2019/09/26      보통
# 2       금융/재무  2019/09/20      보통
# 3       금융/재무  2019/08/21      보통
# 4        연구개발  2018/12/12      보통
# 5       영업/제휴  2018/06/19      보통
# 6       영업/제휴  2018/05/05  매우 어려움
# 7       영업/제휴  2018/04/26      보통
# 8       인사/총무  2017/12/08  매우 어려움
# 9       금융/재무  2017/11/21      보통
# 10  경영/기획/컨설팅  2017/07/19     어려움
# 11      인사/총무  2017/07/04  매우 어려움
# 12      유통/무역  2017/06/28      쉬움
# 13       연구개발  2017/06/02      보통
# 14      영업/제휴  2017/06/02      보통
# 15  경영/기획/컨설팅  2017/06/02   매우 쉬움
# 16      영업/제휴  2017/05/31   매우 쉬움
# 17      영업/제휴  2017/05/30      쉬움
# 18      영업/제휴  2017/05/29      보통
# 19      영업/제휴  2017/02/15      쉬움
#
#                                                  main  \
# 0   "면접자를 배려하는 것이 느껴집니다. 서류 전형 합격 후 면접 안내를 유선상으로 받...
# 1                      "서류접수 ,인성검사 시험 , 면접 이렇게 이루어짐,"
# 2       "특이한 질문이 없었다. 평이한 질문들. 아, 한가지 영어로 설명하는게 있었다."
# 3   "연락이 매우 빠름. 서류합 이후 면접 일주일 정도만에 바로 시작. 면접 끝나고 결...
# 4   "회사 사이즈나 업무를 감안해서, 과분한 고스펙은 자꾸 퇴사하니까 채용을 안하구나 ...
# 5   "1차 2차로 나누어져 있으며 그룹사 면접을 한번에 실시 하는듯 합니다. 1차 실무...
# 6   "인생 역대 최악의 면접이었습니다.\n\n1. 건물은 좀 낡아보입니다. 국내/해외영...
# 7   "먼저, 1차 면접은 영어 면접과 실무진 면접으로 이루어져 있습니다. 영어면접은 당...
# 8   "1차 직무/영어테스트 + 실무진 면접\n\n면접자에 대한 배려가 느껴지는 면접 프...
# 9   "인사팀장? 기획팀장님 오셔서 자소서 기반, 특히 전문직 쪽이라서 그런지 원하는 인...
# 10    "아침에 도착 경영기획 직원 한분이 과제 부여(약 30분 정도 작성)후 면접 진행함"
# 11                       "1차 서류-2차 면접-3차 임원면접 + 과제수행"
# 12  BEST\n"1차면접: 영어시험( 말하기, 쓰기), 실무진 면접\n영어 말하기는 그...
# 13  "면접 30분전 영어작문 : 기본적인 토익주제를 5분안에 작문\n하나의 주제를 던져...
# 14  "먼저 대기실에서 대기한 후 1차면접에 스케줄대로 면접을 차례차례 보게 됩니다. 저...
# 15  "서류 - 온라인 인적성 - 1차 면접(전공필기, 영어(스피킹, 라이팅), 실무진 ...
# 16  "1차 면접 이후 2일 지나서 발표. 2차 면접은 차주에 진행 되며 합격자에 한해 ...
# 17                     "서류전형후 온라인 인적성 진행 2일후 1차면접 실시"
# 18            "서류마감이후 일주일이내 통보 1차면접 다음 2차면접을 본후 최종입사"
# 19  "서류 마감 후 일주일 정도 있다가 연락 옴\n\n1차면접 실무진 면접 (실무진 면...
#
#                                              question  \
# 0                             영어면접, 무역관련 문제풀이, 1대다 면접
# 1                           자기소개, 성격 장단점 등 다양한 질문을 함,
# 2   현금흐름표 구성항목이 무엇인지, 왜 입사 하려고 하는지, 사업내용이 뭔지, 본적 있...
# 3       재무제표란 무엇인가?\n본인의 성격의 장단점이 입사후 어떻게 적용 될 수 있을지?
# 4   -보통의 인생얘기와 뻔한 질문들.. 전공같은거 보다는 인성이나 직무에 대한 생각을 ...
# 5   최종기준 면접관 다대 면접자 이로 최종면접 진행했으며 성장과정이나 본인 성격등 아주...
# 6   영문 면접은 기본적인 일상생활에 대한 면접을 질문합니다.\n본 면접은 기본적인 이력...
# 7   영어면접에서는 간단한 자기소개를 하고 오늘의 날씨에 대해 말해보라고 했습니다. 그리...
# 8                    BSC, 평가보상제도, 노무이슈 등에 대한 견해와 해결방안
# 9           수습 사무실에서 했던 업무 중 우리회사에 적용가능한 업무는 무엇이 있나..
# 10  기획팀 과장이었던거 같은데 굉장히 빠꼼함(질문 난이도 자체 및 경영관리 툴에 대한 ...
# 11  자기소개서 위주의 평이한 질문\n간단한 영어자기소개\n실무상황 제시에 대답하는 형식...
# 12  1차 영어: 제일 친한 친구에 대해서 설명해봐라, 본인 고향에서 가장 유명한 음식 ...
# 13  간단한 자기소개\n오늘 봤던 시사뉴스 토픽하나 그리고 어떻게 생각하는지\nOPAC에...
# 14  면접은 대표이사님 한분과 직급이 높아 보이시는 실무진 두 분, 총 세 분께서 면접관...
# 15  1분 자기소개\n회사에 관하여 아는 것 질문\n재경직무가 뭐하는 것인지\n마지막 어...
# 16  1. 자기소개\n2. 아버지는 어떠시고 직업은 무엇인지?\n3. 어머니는 어떠시고 ...
# 17  주량은 어떻게 되는지\n군생활할때 보람있던일과 힘들었던일\n가장 보람있게 하는일은\...
# 18               자기소개. 기업에대한 관심. 기업직무가 무엇인지등에 대해서 물어봄
# 19  왜 다른 곳에 떨어진 것 같냐\n다른 직무로 가도 상관없는지\n노래방에서 노래 뭐하...
#
#                                                answer
# 0   전반적으로 면접자가 어떤 사람인지 기본적인 사항들을 물어봤고, 타 지역이다보니 거주...
# 1                                    준비한 과정을 토대로 말씀드림
# 2
# 3             그냥 책에 쓰여진 정의 그대로 말함\n성격 부분에서 얼타서 대답 못했음
# 4   뻔한 질문에는 뻔하게 대답했다.\n-내가 지원한 회사에 대해 답변했더니.. 반응이 ...
# 5   예상하지 못한 영어 면접에 당황하여 답변하지 못함. 그 외에는 아주 기본적 인성관련...
# 6         압박면접에 대한 답변은 연이어서 했습니다. 그런데 정말 표정관리가 어렵습니다.
# 7   영어면접에 경우 조금 더듬거리기는 했지만 답변을 계속 이어갔습니다. 실무진 면접에 ...
# 8                        평소 고민을 통해 나름대로 가지고 있던 견해를 말함
# 9   석유쪽 조세특례제한법 관련 업무 소개 및 재산세제 업무 경험 소개. 부가세 신고 등...
# 10                      수행한 업무 중심으로 대답하였으며, 약간의 압박 질문
# 11                                      구체적으로 대답하였습니다
# 12
# 13           질문은 준비를 했지만 안나온 부분은 그 자리에서 재치있게 대답해야합니다.
# 14  면접답변은 제가 생각을 최대한 조리있게 잘 대답하였습니다. 너무 길기 때문에 생략하...
# 15  1분 자기소개 - 졸업 후 공백기간 동안 열심히 살았던 것으로 어필\n홈페이지와 전...
# 16  1. 준비한 것 했습니다\n2. 어금니 꽉 깨물고 얘기했습니다\n3. 어금니 꽉 깨...
# 17  주량은 1병반~2병이라고 대답\n군생활 경험은 자소서 기반으로 썼던내용 답변\n산책...
# 18                                           자기소개. 2병
# 19                  준비가 부족했다\n좋은 경험이라고 생각한다.\n트로트\n2병
